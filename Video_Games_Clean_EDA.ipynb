# %%
import os
import pandas as pd
import numpy as np

# %%
# path to project: Edit here to point to your Drive
drive = '/content/drive/MyDrive/'
project_dir = 'Colab Notebooks/IronHacks2024_Data_Analytics/DA_Week_8-9_Final_Project'
COLAB_PROJECT_PATH = drive+project_dir+'/Final_Project/'

# %%
# Mount Google Drive
using_colab = False
if 'google.colab' in str(get_ipython()):
    from google.colab import drive
    # Mount Google Drive
    drive.mount('/content/drive', force_remount=True)
    using_colab = True

if using_colab and os.path.exists(COLAB_PROJECT_PATH):
    print('found colab path; redirecting to main project directory')
    os.chdir(COLAB_PROJECT_PATH)
# Out:
# Mounted at /content/drive
# found colab path; redirecting to main project directory

# %%
def explore_df(df):
    """
    Explores the dataframe via its dims, dtypes, null counts of each column,
    and value counts for each columns

    Arguments: df (pd.Dataframe) - Dataframe to explore
    Returns: None
    """
    sep_lines = '\n' + '-'*50 + '\n'
    end_lines = '\n' + '='*50 + '\n'
    print("Dataframe shape: ")
    print(f"{df.shape[0]} rows X {df.shape[1]} columns", end=end_lines)

    print("Dataframe data types")
    print(df.dtypes,end=end_lines)

    print(f"Null Count:")
    null_df = pd.concat([df.isnull().sum(), df.isnull().mean()],axis=1)
    null_df.columns = ['count','normalize_count']
    print(null_df, end=end_lines)

    print(f"{df.columns}", end=end_lines)

    cat_from_num = df.select_dtypes("number").loc[:, df.select_dtypes("number").nunique() < 20]
    df_categorical = pd.concat([df.select_dtypes("object"), cat_from_num], axis=1)

    if not df_categorical.empty:
        print("Value counts for each categorical column:")

    for col in df_categorical.columns:
        print(df[col].value_counts(dropna=False),end=sep_lines)

    print(end_lines.strip('\n'))
    if not df_categorical.empty:
        print(df.describe(include='number'), end=sep_lines)
        print(df.describe(include='object'))
    else:
        print(df.describe(include='all'))

# %% [markdown]
# ### Inspect Scraped Data

# %%
vg_data = pd.read_csv('./Original_Scraped_Data/vg_sales_full_data.csv')
vg_data
# Out:
#         Rank                                        Name Platform    Year  \
# 0         32                                  Wii Sports      Wii  2006.0
# 1         52                         Mario Kart 8 Deluxe       NS  2017.0
# 2         81                           Super Mario Bros.      NES  1985.0
# 3         87                              Mario Kart Wii      Wii  2008.0
# 4         94                                      Tetris       GB  1989.0
# ...      ...                                         ...      ...     ...
# 17731  20796                       Brave: The Video Game       DS  2012.0
# 17732  20797            Pippa Funnell 2: Farm Adventures       DS  2007.0
# 17733  20798  Irotoridori no Sekai: World's End Re-Birth      PSV  2015.0
# 17734  20799           PDC World Championship Darts 2009      Wii  2009.0
# 17735  20800    Tears to Tiara: Kakan no Daichi Portable      PSP  2010.0
#
#                   Genre                     Publisher  NA_Sales  EU_Sales  \
# 0                Sports                    Nintendo       41.36     29.02
# 1                Racing                    Nintendo        5.05      4.98
# 2              Platform                    Nintendo       29.08      3.58
# 3                Racing                    Nintendo       15.91     12.92
# 4                Puzzle                    Nintendo       23.20      2.26
# ...                 ...                           ...       ...       ...
# 17731  Action-Adventure  Disney Interactive Studios         NaN      0.01
# 17732        Simulation                     Ubisoft         NaN      0.01
# 17733            Action                       HuneX         NaN       NaN
# 17734            Sports          Oxygen Interactive         NaN      0.01
# 17735         Adventure                    Aquaplus         NaN       NaN
#
#        JP_Sales  Other_Sales  Critic_Score  User_Score
# 0          3.77         8.51           7.7         NaN
# 1          2.11         0.91           9.3         NaN
# 2          6.81         0.77          10.0         8.2
# 3          3.80         3.35           8.2         9.1
# 4          4.22         0.58           NaN         NaN
# ...         ...          ...           ...         ...
# 17731       NaN         0.00           NaN         NaN
# 17732       NaN         0.00           NaN         NaN
# 17733      0.01          NaN           NaN         NaN
# 17734       NaN         0.00           NaN         NaN
# 17735      0.01          NaN           NaN         NaN
#
# [17736 rows x 12 columns]

# %%
explore_df(vg_data)
# Out:
# Dataframe shape:
# 17736 rows X 12 columns
# ==================================================
# Dataframe data types
# Rank              int64
# Name             object
# Platform         object
# Year            float64
# Genre            object
# Publisher        object
# NA_Sales        float64
# EU_Sales        float64
# JP_Sales        float64
# Other_Sales     float64
# Critic_Score    float64
# User_Score      float64
# dtype: object
# ==================================================
# Null Count:
#               count  normalize_count
# Rank              0         0.000000
# Name              0         0.000000
# Platform          0         0.000000
# Year             47         0.002650
# Genre             0         0.000000
# Publisher         0         0.000000
# NA_Sales       4558         0.256991
# EU_Sales       5217         0.294147
# JP_Sales      10947         0.617219
# Other_Sales    2951         0.166385
# Critic_Score  13090         0.738047
# User_Score    17476         0.985341
# ==================================================
# Index(['Rank', 'Name', 'Platform', 'Year', 'Genre', 'Publisher', 'NA_Sales',
#        'EU_Sales', 'JP_Sales', 'Other_Sales', 'Critic_Score', 'User_Score'],
#       dtype='object')
# ==================================================
# Value counts for each categorical column:
# Name
# Ratatouille                                    9
# Madden NFL 07                                  9
# FIFA 14                                        9
# Cars                                           8
# Minecraft                                      8
#                                               ..
# Transformers: War for Cybertron -- Autobots    1
# Butt Ugly Martians: B.K.M. Battles             1
# Sorry! / Aggravation / Scrabble Junior         1
# NBA Courtside 2002                             1
# Tears to Tiara: Kakan no Daichi Portable       1
# Name: count, Length: 12184, dtype: int64
# --------------------------------------------------
# Platform
# PS2     2118
# DS      2097
# PS3     1321
# Wii     1298
# X360    1252
# PS      1195
# PSP     1152
# PC      1044
# PS4      881
# XB       815
# GBA      810
# 3DS      576
# GC       544
# XOne     519
# PSV      514
# N64      320
# SNES     241
# NS       238
# SAT      175
# WiiU     158
# 2600     133
# NES      100
# GB        94
# DC        52
# GEN       30
# NG        12
# PSN       10
# GBC        8
# SCD        6
# WS         6
# XBL        4
# 3DO        4
# VC         2
# PCE        2
# WW         1
# GG         1
# OSX        1
# PCFX       1
# Mob        1
# Name: count, dtype: int64
# --------------------------------------------------
# Genre
# Action              2722
# Sports              2457
# Misc                1757
# Role-Playing        1641
# Adventure           1512
# Shooter             1427
# Racing              1340
# Platform            1021
# Simulation           985
# Fighting             910
# Strategy             720
# Puzzle               603
# Action-Adventure     279
# Visual Novel         143
# Music                141
# MMO                   38
# Party                 33
# Education              4
# Board Game             2
# Sandbox                1
# Name: count, dtype: int64
# --------------------------------------------------
# Publisher
# Activision                 1004
# Ubisoft                     911
# Electronic Arts             803
# Konami                      740
# Nintendo                    737
#                            ...
# Athena                        1
# Aria                          1
# Fortyfive                     1
# Imax                          1
# Interplay Productions         1
# Name: count, Length: 649, dtype: int64
# --------------------------------------------------
# ==================================================
#                Rank          Year      NA_Sales      EU_Sales     JP_Sales  \
# count  17736.000000  17689.000000  13178.000000  12519.000000  6789.000000
# mean   11110.313938   2007.376449      0.356921      0.214953     0.203808
# std     5836.595613      6.419897      0.917812      0.613797     0.469608
# min       32.000000   1977.000000      0.000000      0.000000     0.000000
# 25%     6160.750000   2004.000000      0.060000      0.020000     0.030000
# 50%    11229.500000   2008.000000      0.130000      0.060000     0.070000
# 75%    16250.250000   2011.000000      0.340000      0.185000     0.190000
# max    20800.000000   2070.000000     41.360000     29.020000    10.220000
#
#         Other_Sales  Critic_Score  User_Score
# count  14785.000000   4646.000000  260.000000
# mean       0.059060      7.278713    8.415769
# std        0.204924      1.416421    1.267937
# min        0.000000      1.000000    2.000000
# 25%        0.000000      6.500000    8.000000
# 50%        0.010000      7.500000    8.700000
# 75%        0.050000      8.300000    9.300000
# max       10.570000     10.000000   10.000000
# --------------------------------------------------
#                Name Platform   Genre     Publisher
# count         17736    17736   17736         17736
# unique        12184       39      20           649
# top     Ratatouille      PS2  Action  Activision
# freq              9     2118    2722          1004

# %% [markdown]
# ### Erroneous Year entries in 5 games : Should remove them in cleaning function

# %%
print(vg_data['Year'].value_counts(dropna=False).sort_index(ascending=False).iloc[:10], end='-'*20)

vg_data[vg_data['Year'] == 2070.0] # error in scraper code, but these entries had been set to jan 1st 1970
# Out:
# Year
# 2070.0      5
# 2020.0     21
# 2019.0     28
# 2018.0    565
# 2017.0    632
# 2016.0    613
# 2015.0    605
# 2014.0    565
# 2013.0    512
# 2012.0    653
# Name: count, dtype: int64--------------------
#         Rank                                            Name Platform    Year  \
# 7541    9691                Danganronpa: Trigger Happy Havoc      PSP  2070.0
# 8023   10236                                 Ghostbusters II     2600  2070.0
# 8064   10281  Valkyria Chronicles III: Unrecorded Chronicles      PSP  2070.0
# 14754  17753                                  Check vs. Mate      PS3  2070.0
# 17683  20748               WRC: FIA World Rally Championship       PC  2070.0
#
#               Genre  Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# 7541      Adventure  Unknown         NaN       NaN      0.24          NaN
# 8023         Action  Unknown         0.2      0.01       NaN         0.00
# 8064   Role-Playing  Unknown         NaN       NaN      0.21          NaN
# 14754          Misc  Unknown         NaN      0.04       NaN         0.01
# 17683        Racing  Unknown         NaN      0.01       NaN         0.00
#
#        Critic_Score  User_Score
# 7541            NaN         NaN
# 8023            NaN         NaN
# 8064            NaN         NaN
# 14754           NaN         NaN
# 17683           NaN         NaN

# %% [markdown]
# ### Looking at Plaform Data
# - There are

# %%
platform_counts = vg_data['Platform'].value_counts()
invalid_platforms = platform_counts[platform_counts < 10].index
drop_invalid_platform = vg_data[vg_data['Platform'].isin(invalid_platforms)].index
vg_data[vg_data['Platform'].isin(invalid_platforms)]
# Out:
#         Rank                                              Name Platform  \
# 175      642                           Pokémon Crystal Version      GBC
# 233      741                                   Pokémon Pinball      GBC
# 869     1753          The Legend of Zelda: Link's Awakening DX      GBC
# 887     1782                               Donkey Kong Country      GBC
# 1060    2046               The Legend of Zelda: Oracle of Ages      GBC
# 1088    2083                                         Tetris DX      GBC
# 1097    2094            The Legend of Zelda: Oracle of Seasons      GBC
# 1455    2538                                          Sonic CD      SCD
# 3999    5604                          Hamtaro: Ham-Hams Unite!      GBC
# 4337    5972                                     Final Fantasy       WS
# 6687    8695                    Digimon Adventure: Anode Tamer       WS
# 6917    8948                                       Punch-Out!!       VC
# 7271    9339                                  Final Fantasy II       WS
# 7311    9422                              Karaoke Joysound Wii       WW
# 8299   10579                                             Worms      XBL
# 8740   11072         Chocobo no Fushigi Dungeon for WonderSwan       WS
# 9008   11391             Super Robot Taisen Compact 2 Dai-1-Bu       WS
# 9792   12341                                  Shining Force CD      SCD
# 10016  12601                                        Doukyuusei      PCE
# 10482  13150                     Grand Theft Auto: San Andreas      XBL
# 11946  14869                     Super Street Fighter II Turbo      3DO
# 12756  15698  Formula One World Championship: Beyond the Limit      SCD
# 13193  16142                                      Mario Tennis       VC
# 13663  16626                Record of Lodoss War: Eiyuu Sensou      SCD
# 13726  16689                                       Policenauts      3DO
# 14096  17062                             Game no Kanzume Vol 2      SCD
# 14629  17626                             Game no Kanzume Vol 1      SCD
# 14722  17721                              Sonic the Hedgehog 2       GG
# 15494  18508             SD Gundam G Generation: Gather Beat 2       WS
# 15659  18675                Majesty 2: The Fantasy Kingdom Sim      OSX
# 15942  18970                Blue Breaker: Ken Yorimo Hohoemi o     PCFX
# 15957  18985             Forza Motorsport 4: December IGN Pack      XBL
# 16009  19037                                   Resident Evil 4      Mob
# 16441  19482                                       Bust-A-Move      3DO
# 16656  19700            Castlevania: Lords of Shadow - Reverie      XBL
# 17010  20061              Sotsugyou II: Neo Generation Special      3DO
# 17069  20121                    Ginga Fukei Densetsu: Sapphire      PCE
#
#          Year         Genre                      Publisher  NA_Sales  \
# 175    2001.0  Role-Playing                     Nintendo        2.55
# 233    1999.0          Misc                     Nintendo        3.02
# 869    1998.0     Adventure                     Nintendo        1.00
# 887    2000.0      Platform                     Nintendo        1.04
# 1060   2001.0     Adventure                     Nintendo        0.92
# 1088   1998.0        Puzzle                     Nintendo        1.06
# 1097   2001.0     Adventure                     Nintendo        0.87
# 1455   1993.0      Platform                         Sega        1.00
# 3999   2002.0  Role-Playing                     Nintendo         NaN
# 4337   2000.0  Role-Playing                       Square         NaN
# 6687   1999.0  Role-Playing                       Bandai         NaN
# 6917   2007.0        Sports                     Nintendo        0.00
# 7271   2001.0  Role-Playing                       Square         NaN
# 7311   2009.0          Misc                  Hudson Soft        0.00
# 8299   2007.0      Strategy                    Microsoft         NaN
# 8740   1999.0  Role-Playing                       Bandai         NaN
# 9008   2000.0      Strategy                       Bandai         NaN
# 9792   1994.0      Strategy                         Sega         NaN
# 10016  1995.0     Adventure                          NEC         NaN
# 10482  2008.0        Action               Rockstar Games        0.09
# 11946  1994.0      Fighting  Panasonic Interactive Media         NaN
# 12756  1994.0        Racing                         Sega         NaN
# 13193  2010.0        Sports                     Nintendo         NaN
# 13663  1994.0  Role-Playing                         Sega         NaN
# 13726  1995.0     Adventure                       Konami         NaN
# 14096  1994.0          Misc                         Sega         NaN
# 14629  1994.0          Misc                         Sega         NaN
# 14722  1992.0      Platform                         Sega         NaN
# 15494  2001.0      Strategy                       Bandai         NaN
# 15659  2009.0      Strategy         Paradox Interactive         0.03
# 15942  1996.0  Role-Playing                          NEC         NaN
# 15957  2011.0        Racing            Microsoft Studios        0.01
# 16009  2009.0          Misc                       Capcom         NaN
# 16441  1995.0        Puzzle  Panasonic Interactive Media         NaN
# 16656  2011.0        Action                       Konami        0.02
# 17010  1995.0    Simulation                   Imageworks         NaN
# 17069  1995.0       Shooter                  Hudson Soft         NaN
#
#        EU_Sales  JP_Sales  Other_Sales  Critic_Score  User_Score
# 175        1.56      1.29         0.99           8.7         NaN
# 233        1.12      1.01         0.16           8.7         NaN
# 869        0.63      0.45         0.13           9.4         NaN
# 887        0.72      0.30         0.13           9.1         NaN
# 1060       0.53      0.41         0.06           9.4         NaN
# 1088       0.60      0.20         0.07           NaN         NaN
# 1097       0.52      0.41         0.06           9.3         NaN
# 1455       0.36      0.09         0.05           NaN         NaN
# 3999        NaN      0.56         0.00           NaN         NaN
# 4337        NaN      0.51          NaN           NaN         NaN
# 6687        NaN      0.28          NaN           NaN         NaN
# 6917       0.22      0.05          NaN           NaN         NaN
# 7271        NaN      0.25         0.00           NaN         NaN
# 7311        NaN      0.25          NaN           NaN         NaN
# 8299       0.02       NaN         0.00           NaN         NaN
# 8740        NaN      0.18         0.00           NaN         NaN
# 9008        NaN      0.17          NaN           NaN         NaN
# 9792        NaN      0.14          NaN           NaN         NaN
# 10016       NaN      0.14          NaN           NaN         NaN
# 10482      0.02       NaN         0.01           NaN         NaN
# 11946       NaN      0.09          NaN           NaN         NaN
# 12756       NaN      0.07          NaN           NaN         NaN
# 13193      0.06      0.00         0.01           NaN         NaN
# 13663       NaN      0.06         0.00           NaN         NaN
# 13726       NaN      0.06          NaN           NaN         NaN
# 14096       NaN      0.05         0.00           NaN         NaN
# 14629       NaN      0.04         0.00           NaN         NaN
# 14722       NaN      0.04          NaN           NaN         NaN
# 15494       NaN      0.03          NaN           NaN         NaN
# 15659       NaN       NaN         0.00           NaN         NaN
# 15942       NaN      0.03          NaN           NaN         NaN
# 15957      0.02       NaN         0.00           NaN         NaN
# 16009      0.02       NaN         0.00           NaN         NaN
# 16441       NaN      0.02          NaN           NaN         NaN
# 16656      0.00       NaN         0.00           NaN         NaN
# 17010       NaN      0.02          NaN           NaN         NaN
# 17069       NaN      0.02          NaN           NaN         NaN

# %%
type_games = vg_data[vg_data['Platform'] =='Mob']
type_games
# Out:
#         Rank             Name Platform    Year Genre Publisher  NA_Sales  \
# 16009  19037  Resident Evil 4      Mob  2009.0  Misc  Capcom         NaN
#
#        EU_Sales  JP_Sales  Other_Sales  Critic_Score  User_Score
# 16009      0.02       NaN          0.0           NaN         NaN

# %%
vg_data.columns
# Out:
# Index(['Rank', 'Name', 'Platform', 'Year', 'Genre', 'Publisher', 'NA_Sales',
#        'EU_Sales', 'JP_Sales', 'Other_Sales', 'Critic_Score', 'User_Score'],
#       dtype='object')

# %% [markdown]
# ## Cleaning Data

# %% [markdown]
# ### Strategy for dealing witht the null values:
# - Years: only a few entries, probably can afford to drop those rows
# - Sales columns: probably fill those nulls with zeros
# - User Score and Critic Score: fill them with zeros or -1.0

# %% [markdown]
# ### Dealing w/ Unknown Publisher
# for game entries with publishers labeled unknown, We can drop those rows.

# %%
# Before cleaning
end_line = '\n' + '-' * 50 + '\n'
print(np.sort(vg_data['Year'].unique())[::-1], end = end_line)
print(vg_data['Platform'].value_counts(dropna=False), end = end_line)
print(vg_data['Publisher'].value_counts(dropna=False), end = end_line)
print('How many Unknown publisher entries: ', \
      vg_data['Publisher'].value_counts().get('Unknown  ','None'))
# Out:
# [  nan 2070. 2020. 2019. 2018. 2017. 2016. 2015. 2014. 2013. 2012. 2011.
#  2010. 2009. 2008. 2007. 2006. 2005. 2004. 2003. 2002. 2001. 2000. 1999.
#  1998. 1997. 1996. 1995. 1994. 1993. 1992. 1991. 1990. 1989. 1988. 1987.
#  1986. 1985. 1984. 1983. 1982. 1981. 1980. 1979. 1978. 1977.]
# --------------------------------------------------
# Platform
# PS2     2118
# DS      2097
# PS3     1321
# Wii     1298
# X360    1252
# PS      1195
# PSP     1152
# PC      1044
# PS4      881
# XB       815
# GBA      810
# 3DS      576
# GC       544
# XOne     519
# PSV      514
# N64      320
# SNES     241
# NS       238
# SAT      175
# WiiU     158
# 2600     133
# NES      100
# GB        94
# DC        52
# GEN       30
# NG        12
# PSN       10
# GBC        8
# SCD        6
# WS         6
# XBL        4
# 3DO        4
# VC         2
# PCE        2
# WW         1
# GG         1
# OSX        1
# PCFX       1
# Mob        1
# Name: count, dtype: int64
# --------------------------------------------------
# Publisher
# Activision                 1004
# Ubisoft                     911
# Electronic Arts             803
# Konami                      740
# Nintendo                    737
#                            ...
# Athena                        1
# Aria                          1
# Fortyfive                     1
# Imax                          1
# Interplay Productions         1
# Name: count, Length: 649, dtype: int64
# --------------------------------------------------
# How many Unknown publisher entries:  134

# %%
def data_below_threshold(data, col:str='', threshold:int=10):
    """
    Util function that grabs dataframe of entries below certain
    count threshold in one of its columns

    arguments: data (pd,dataframe) - dataframe to extract entries below threshold
               col : column for the threshold filtering
               threshold : threshold for grabbing entries with counts below it
    returns:   The filtered dataframe with entries in col below threshold
    """
    col_counts = data[col].value_counts()
    invalid_rows = col_counts[col_counts < threshold].index
    data_below = data[data[col].isin(invalid_rows)]

    #print(data_below[col].value_counts(), end = '\n'+'-'*40+'\n')

    return data_below

def clean_nulls(vg_chartz_df, drop_nulls, fill_nulls):
    """
    Clean the nulls out (drop/fill them)

    arguments: vg_chartz_df (pd,dataframe) - dataframe to clean nulls
               drop_nulls (List(str)) - columns to drop nulls for
               fill_nulls (Dict(str, )) - columns to fill nulls with value
    """
    for drop_col in drop_nulls:
        vg_chartz_df.dropna(subset=[drop_col], inplace=True)

    for fill_col in fill_nulls:
        fill = fill_nulls[fill_col]
        vg_chartz_df[fill_col].fillna(fill, inplace=True)

# %%
def clean_data(vg_chartz_df):
    """
    Clean the scraped data from vgchartz:
     - drops rows with erronous year values and
     - drop rows with platforms/Genres that don't really show up much (threshold is 20)
     - clean nulls (using seperate function)
     arguments: vg_chartz_df (pd.DataFrame) - Dataframe with the scraped vgchartz data
    """
    # THRESHOLD FOR FILTERING PLATFORMS & Genre
    min_plat = 20
    min_genre = 20

    # Cleaning out game entries with erroneous year 2070
    bad_year = vg_chartz_df['Year'] == 2070.0
    vg_chartz_df.drop(vg_chartz_df[bad_year].index, inplace=True)

    # Clean out platforms that didn't meet min threshold of entries
    invalid_platform = data_below_threshold(vg_chartz_df, 'Platform', min_plat)
    drop_invalid_platform = invalid_platform.index
    vg_chartz_df.drop(drop_invalid_platform, inplace=True)

    # Clean out Genre that didn't meet min threshold of entries
    invalid_genre = data_below_threshold(vg_chartz_df, 'Genre', min_plat)
    drop_invalid_genre = invalid_genre.index
    vg_chartz_df.drop(drop_invalid_genre, inplace=True)

    # Cleaning Publisher name entries and replacing Unknown with NaNs for drop
    vg_data['Publisher'] = vg_data['Publisher'].str.strip()
    vg_data['Publisher'].replace('Unknown', pd.NA, inplace=True)

    # Vara representing columns in data to clean nulls for
    drop_cols = ['Year', 'Publisher']
    sale_cols = ['NA_Sales', 'EU_Sales', 'JP_Sales', 'Other_Sales']
    score_cols = ['Critic_Score', 'User_Score']

    score_fill = {score: 0.0 for score in score_cols}
    fill_cols = {sales : 0.0 for sales in sale_cols}
    fill_cols.update(score_fill)

    # Cleaning nulls
    clean_nulls(vg_chartz_df, drop_cols, fill_cols)

# %% [markdown]
# ### Look at Results of Cleaning

# %%
clean_data(vg_data)

end_line = '\n' + '-' * 50 + '\n'
print(np.sort(vg_data['Year'].unique())[::-1], end = end_line)
print(vg_data['Platform'].value_counts(dropna=False), end = end_line)
print(vg_data['Publisher'].value_counts(dropna=False), end = end_line)
print(vg_data['Genre'].value_counts(dropna=False), end = end_line)
print('How many null publisher entries: ', \
      vg_data['Publisher'].value_counts().get(pd.NA,'None'), end = end_line)
print('Nulls in scores: ')
print(f"{vg_data['Critic_Score'].isna().sum()=}")
print(f"{vg_data['User_Score'].isna().sum()=}")
# Out:
# [2020. 2019. 2018. 2017. 2016. 2015. 2014. 2013. 2012. 2011. 2010. 2009.
#  2008. 2007. 2006. 2005. 2004. 2003. 2002. 2001. 2000. 1999. 1998. 1997.
#  1996. 1995. 1994. 1993. 1992. 1991. 1990. 1989. 1988. 1987. 1986. 1985.
#  1984. 1983. 1982. 1981. 1980. 1979. 1978. 1977.]
# --------------------------------------------------
# Platform
# PS2     2110
# DS      2062
# PS3     1307
# Wii     1285
# X360    1237
# PS      1193
# PSP     1141
# PC      1023
# PS4      881
# XB       815
# GBA      808
# 3DS      571
# GC       541
# XOne     519
# PSV      509
# N64      318
# SNES     241
# NS       235
# SAT      174
# WiiU     158
# 2600     127
# NES      100
# GB        94
# DC        52
# GEN       30
# Name: count, dtype: int64
# --------------------------------------------------
# Publisher
# Activision               1004
# Ubisoft                   909
# Electronic Arts           803
# Konami                    737
# Nintendo                  726
#                          ...
# Evolution Games             1
# Athena                      1
# Aria                        1
# Fortyfive                   1
# Interplay Productions       1
# Name: count, Length: 645, dtype: int64
# --------------------------------------------------
# Genre
# Action              2697
# Sports              2445
# Misc                1727
# Role-Playing        1616
# Adventure           1494
# Shooter             1424
# Racing              1327
# Platform            1011
# Simulation           972
# Fighting             891
# Strategy             709
# Puzzle               585
# Action-Adventure     279
# Visual Novel         143
# Music                141
# MMO                   37
# Party                 33
# Name: count, dtype: int64
# --------------------------------------------------
# How many null publisher entries:  None
# --------------------------------------------------
# Nulls in scores:
# vg_data['Critic_Score'].isna().sum()=0
# vg_data['User_Score'].isna().sum()=0

# %%
drop_cols = ['Year', 'Publisher']
sale_cols = ['NA_Sales', 'EU_Sales', 'JP_Sales', 'Other_Sales']
score_cols = ['Critic_Score', 'User_Score']

score_fill = {score: 0.0 for score in score_cols}
fill_cols = {sales : 0.0 for sales in sale_cols}
fill_cols.update(score_fill)

all_cols = drop_cols + sale_cols
for disp_col in all_cols:
    print(vg_data[disp_col].value_counts(dropna=False))
# Out:
# Year
# 2009.0    1441
# 2008.0    1381
# 2010.0    1283
# 2011.0    1147
# 2007.0    1127
# 2006.0     965
# 2005.0     936
# 2002.0     791
# 2003.0     783
# 2004.0     769
# 2012.0     643
# 2017.0     631
# 2016.0     609
# 2015.0     603
# 2018.0     564
# 2014.0     562
# 2013.0     511
# 2001.0     489
# 2000.0     394
# 1999.0     355
# 1998.0     340
# 1996.0     284
# 1997.0     259
# 1995.0     181
# 1994.0      94
# 1993.0      58
# 1982.0      45
# 1992.0      39
# 1983.0      36
# 1991.0      33
# 2019.0      28
# 1990.0      21
# 1986.0      18
# 1989.0      18
# 1988.0      16
# 1987.0      16
# 1985.0      15
# 1984.0      12
# 1978.0       9
# 2020.0       9
# 1981.0       7
# 1980.0       5
# 1977.0       3
# 1979.0       1
# Name: count, dtype: int64
# Publisher
# Activision               1004
# Ubisoft                   909
# Electronic Arts           803
# Konami                    737
# Nintendo                  726
#                          ...
# Evolution Games             1
# Athena                      1
# Aria                        1
# Fortyfive                   1
# Interplay Productions       1
# Name: count, Length: 645, dtype: int64
# NA_Sales
# 0.00    4482
# 0.04     654
# 0.02     644
# 0.03     632
# 0.05     622
#         ...
# 2.63       1
# 4.01       1
# 3.76       1
# 3.68       1
# 3.47       1
# Name: count, Length: 420, dtype: int64
# EU_Sales
# 0.00    6208
# 0.01    1412
# 0.02    1317
# 0.03     992
# 0.04     756
#         ...
# 5.13       1
# 6.46       1
# 3.34       1
# 2.37       1
# 2.62       1
# Name: count, Length: 324, dtype: int64
# JP_Sales
# 0.00    11018
# 0.02      848
# 0.03      623
# 0.01      529
# 0.04      467
#         ...
# 1.58        1
# 2.49        1
# 2.23        1
# 3.28        1
# 1.46        1
# Name: count, Length: 244, dtype: int64
# Other_Sales
# 0.00    6612
# 0.01    3698
# 0.02    1795
# 0.03    1002
# 0.04     692
#         ...
# 1.28       1
# 2.28       1
# 1.20       1
# 2.26       1
# 0.75       1
# Name: count, Length: 163, dtype: int64

# %% [markdown]
# Was Looking at amount of Publishers with very few entries to consider whether to drop or not
#
# Ultimately decided not to drop any publishers: we should include games from obscure publishers.

# %%
### how many Publishers have less than 5 entries in data
pub_min = 10
pub_data = data_below_threshold(vg_data, 'Publisher', pub_min)
print(pub_data.shape[0], f' below threshold of {pub_min} published games')
# Out:
# 1206  below threshold of 10 published games

# %%
# storing cleaned data to a file for later use
vg_data.to_csv('./Clean_Data/vg_sales_cleaned.csv', index=False)

# %% [markdown]
# ## Time to Prep the data for K-means Clustering

# %% [markdown]
# ### Go to Data Modeling Notebook Next
